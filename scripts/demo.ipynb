# %%
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt

import configparser
config = configparser.ConfigParser()
config.read('../src/config.ini')

import warnings
warnings.filterwarnings("ignore")

# %%
DataPath = config.get('base', 'DataPath')
df = pd.read_excel(DataPath + 'CaseOzone.xlsx',index_col=0)
df.columns
# Out:
# Index(['NO_airship', 'NO2_airship', 'Nox_airship', 'O3_airship', 'Ox_airship',
#        'Height_TraceGas_PTR_airship_height', 'Temperature_airship',
#        'RH_airship', 'Pressure_airship', 'WS_airship', 'WD_airship',
#        'Height_Meteor_airship_height', 'NO_ground', 'NO2_ground', 'Nox_ground',
#        'O3_ground', 'Ox_ground', 'Temperature_ground', 'RH_ground',
#        'Pressure_ground', 'WS_ground', 'WD_ground', 'Rain_ground'],
#       dtype='object')

# %%
O3_grd = df['O3_ground']
O3_air = df['O3_airship']

# %%
O3_grd.plot()
# Out:
# <Axes: >
